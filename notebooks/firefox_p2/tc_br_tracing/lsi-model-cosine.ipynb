# %% [markdown]
# # Introduction - Using COSINE Metric
#
# In this notebook we demonstrate the use of **LSI (Latent Semantic Indexing)** technique of Information Retrieval context to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each use case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd

from modules.models_runner.tc_br_models_runner import TC_BR_Runner
from modules.models_runner.tc_br_models_runner import TC_BR_Models_Hyperp
from modules.utils import aux_functions
from modules.utils import firefox_dataset_p2 as fd

import modules.utils.tokenizers as tok

from modules.models.lsi import LSI

from IPython.display import display

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load Datasets

# %%
tcs = [x for x in range(37,59)]
orc = fd.Tc_BR_Oracles.read_oracle_expert_df()
orc_subset = orc[orc.index.isin(tcs)]
#aux_functions.highlight_df(orc_subset)
# Out:
# OracleExpert.shape: (195, 91)

# %%
tcs = [13,37,60,155]
brs = [1292566,1267501]

testcases = fd.Datasets.read_testcases_df()
testcases = testcases[testcases.TC_Number.isin(tcs)]
bugreports = fd.Datasets.read_selected_bugreports_df()
bugreports = bugreports[bugreports.Bug_Number.isin(brs)]

print('tc.shape: {}'.format(testcases.shape))
print('br.shape: {}'.format(bugreports.shape))
# Out:
# TestCases.shape: (195, 12)
# SelectedBugReports.shape: (91, 18)
# tc.shape: (4, 12)
# br.shape: (2, 18)

# %%
print(bugreports.iloc[0,:].Summary)
bugreports
# Out:
# New Private Browsing start-page overflows off the *left side of the window* (making content unscrollable) for small window sizes
#     Bug_Number                                            Summary  \
# 6      1267501  New Private Browsing start-page overflows off ...
# 32     1292566  The "open" button in the subview for temporari...
#
#        Platform         Component    Version         Creation_Time  \
# 6   Unspecified  Private Browsing  48 Branch  2016-04-26T01:12:11Z
# 32  Unspecified   Downloads Panel  50 Branch  2016-08-05T14:16:47Z
#
#      Whiteboard QA_Whiteboard  \
# 6   [fxprivacy]           NaN
# 32  [fxprivacy]           NaN
#
#                                    First_Comment_Text  \
# 6   STR:  1. Open a new private browsing window.  ...
# 32  The Downloads Panel subview for blocked downlo...
#
#    First_Comment_Creation_Time    Status  Product Priority Resolution  \
# 6         2016-04-26T01:12:11Z  RESOLVED  Firefox       P1      FIXED
# 32        2016-08-05T14:16:47Z  VERIFIED  Firefox       P2      FIXED
#
#    Severity  Is_Confirmed         br_name  \
# 6    normal          True  BR_1267501_SRC
# 32   normal          True  BR_1292566_SRC
#
#                                               br_desc
# 6   1267501 New Private Browsing start-page overfl...
# 32  1292566 The "open" button in the subview for t...

# %%
testcases
# Out:
#      TC_Number                         TestDay  Feature_ID  \
# 12          13  20160603 + 20160624 + 20161014           1
# 36          37             20160603 + 20160708           3
# 59          60                        20160722           4
# 154        155                        20161028          15
#
#            Firefox_Feature              Gen_Title  Crt_Nr  \
# 12         New Awesome Bar     Awesome Bar Search       1
# 36   APZ - Async Scrolling  APZ - Async Scrolling       1
# 59   Browser Customization  browser customization       2
# 154    Downloads Dropmaker    downloads dropmaker       3
#
#                                                  Title  \
# 12                                       Default State
# 36                      Scroll through a long web page
# 59                     Install and use complete themes
# 154  The downloads button works properly no matter ...
#
#                                          Preconditions  \
# 12                                                 NaN
# 36   - make sure layers.async-pan-zoom.enabled is t...
# 59                                                 NaN
# 154
#
#                                                  Steps  \
# 12        1. Launch Firefox.\t\n2. No AwesomeBar Entry
# 36   1. Launch Firefox.\t\n2. Open: https://en.wiki...
# 59   1. Install a few complete themes.\n2. Restart ...
# 154  1. Launch Firefox with a clean profile\t\n2. C...
#
#                                        Expected_Result     tc_name  \
# 12   1. Firefox launches without any issues.\n2. UR...   TC_13_TRG
# 36   1. \n2.\n3. The scrolling is smooth, without a...   TC_37_TRG
# 59   1. The user is able to initiate installation p...   TC_60_TRG
# 154  1. Firefox is successfully launched\n2. Custom...  TC_155_TRG
#
#                                                tc_desc
# 12   13 20160603 + 20160624 + 20161014 1 New Awesom...
# 36   37 20160603 + 20160708 3 APZ - Async Scrolling...
# 59   60 20160722 4 Browser Customization browser cu...
# 154  155 20161028 15 Downloads Dropmaker downloads ...

# %% [markdown]
# # Running LSI Model

# %%
corpus = testcases.tc_desc
query = bugreports.br_desc
test_cases_names = testcases.tc_name
bug_reports_names = bugreports.br_name

lsi_hyperp = TC_BR_Models_Hyperp.get_lsi_model_hyperp()
lsi_model = LSI(**lsi_hyperp)
lsi_model.set_name('LSI_Model_TC_BR')
lsi_model.recover_links(corpus, query, test_cases_names, bug_reports_names)
# Out:
#  ..Total processing time: 1.12 seconds

# %%
lsi_model.get_sim_matrix().shape
# Out:
# (4, 2)

# %%
sim_matrix = lsi_model.get_sim_matrix()
aux_functions.highlight_df(sim_matrix)
# Out:
# <style  type="text/css" >
#     #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow0_col0 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow0_col1 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow1_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow3_col0 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2ea" ><thead>    <tr>        <th class="index_name level0" >br_name</th>        <th class="col_heading level0 col0" >BR_1267501_SRC</th>        <th class="col_heading level0 col1" >BR_1292566_SRC</th>    </tr>    <tr>        <th class="index_name level0" >tc_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2ealevel0_row0" class="row_heading level0 row0" >TC_13_TRG</th>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow0_col0" class="data row0 col0" >0.470123</td>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow0_col1" class="data row0 col1" >0.0679615</td>
#             </tr>
#             <tr>
#                         <th id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2ealevel0_row1" class="row_heading level0 row1" >TC_37_TRG</th>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow1_col0" class="data row1 col0" >0.932144</td>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow1_col1" class="data row1 col1" >0.092866</td>
#             </tr>
#             <tr>
#                         <th id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2ealevel0_row2" class="row_heading level0 row2" >TC_60_TRG</th>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow2_col0" class="data row2 col0" >0.0698727</td>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow2_col1" class="data row2 col1" >0.0449254</td>
#             </tr>
#             <tr>
#                         <th id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2ealevel0_row3" class="row_heading level0 row3" >TC_155_TRG</th>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow3_col0" class="data row3 col0" >0.158545</td>
#                         <td id="T_b294ceb2_85f1_11eb_a7e0_09e1e13bf2earow3_col1" class="data row3 col1" >0.997955</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### TF-IDF Application

# %%
print(bugreports.Summary.values[0])
print(bugreports.First_Comment_Text.values[0])
# Out:
# New Private Browsing start-page overflows off the *left side of the window* (making content unscrollable) for small window sizes
# STR:  1. Open a new private browsing window.  2. Resize the window to be skinny, say 300-400px wide.  3. Try to scroll around horizontally to read the page's contents (using the scrollbars).  ACTUAL RESULTS: - If you scroll all the way to the left, you'll see that the page's contents overflow off the left side of the viewport, to the extent that they're unscrollable and hence unreadable. - If you scroll all the way to the right, you'll see that the page's background-color ends abruptly, and some text protrudes past that.   EXPECTED RESULTS: * Contents should be scrollable/readable. * No awkward background-color-ending in the region of the viewport that is scrollable.

# %%
q = query.values[0]

tok = lsi_model.vectorizer.tokenizer
words_list = tok.__call__(q)

from collections import Counter
wordcount = Counter(words_list).most_common()

df = pd.DataFrame(columns=['term','tf',''])

print(wordcount)
# Out:
# [('private', 3), ('browsing', 3), ('content', 3), ('window', 3), ('scroll', 3), ('page', 3), ('new', 2), ('overflow', 2), ('side', 2), ('unscrollable', 2), ('results', 2), ('if', 2), ('way', 2), ('left', 2), ('see', 2), ('viewport', 2), ('making', 1), ('small', 1), ('size', 1), ('unspecified', 1), ('branch', 1), ('fxprivacy', 1), ('nan', 1), ('str', 1), ('open', 1), ('resize', 1), ('skinny', 1), ('say', 1), ('wide', 1), ('try', 1), ('around', 1), ('horizontally', 1), ('read', 1), ('using', 1), ('scrollbars', 1), ('actual', 1), ('extent', 1), ('hence', 1), ('unreadable', 1), ('right', 1), ('end', 1), ('abruptly', 1), ('text', 1), ('protrudes', 1), ('past', 1), ('expected', 1), ('contents', 1), ('no', 1), ('awkward', 1), ('region', 1), ('scrollable', 1), ('resolved', 1), ('firefox', 1), ('fixed', 1), ('normal', 1), ('true', 1)]

# %%
lsi_model.get_svd_matrix().shape
# Out:
# (4, 4)

# %%
svd_matrix = pd.DataFrame(lsi_model.get_svd_matrix())
#svd_matrix.index = test_cases_names
aux_functions.highlight_df(svd_matrix)
# Out:
# <style  type="text/css" >
#     #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col1 {
#             background-color:  #b3e3b3;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col2 {
#             background-color:  #b3e3b3;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col0 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col2 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col3 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col0 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col1 {
#             background-color:  #8acc8a;
#             color:  #000000;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col3 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }</style><table id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2ea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2ealevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col0" class="data row0 col0" >0.720291</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col1" class="data row0 col1" >-0.0532987</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col2" class="data row0 col2" >-0.127135</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow0_col3" class="data row0 col3" >0.679835</td>
#             </tr>
#             <tr>
#                         <th id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2ealevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col0" class="data row1 col0" >0.635239</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col1" class="data row1 col1" >-0.332496</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col2" class="data row1 col2" >-0.399589</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow1_col3" class="data row1 col3" >-0.57118</td>
#             </tr>
#             <tr>
#                         <th id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2ealevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col0" class="data row2 col0" >0.180721</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col1" class="data row2 col1" >0.926883</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col2" class="data row2 col2" >-0.30391</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow2_col3" class="data row2 col3" >-0.125959</td>
#             </tr>
#             <tr>
#                         <th id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2ealevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col0" class="data row3 col0" >0.48101</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col1" class="data row3 col1" >0.170679</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col2" class="data row3 col2" >0.832273</td>
#                         <td id="T_b2a29466_85f1_11eb_a7e0_09e1e13bf2earow3_col3" class="data row3 col3" >-0.216379</td>
#             </tr>
#     </tbody></table>

# %%
len(lsi_model.vectorizer.get_feature_names())
# Out:
# 98

# %%
import modules.utils.tokenizers as tok

tokenizer = tok.WordNetBased_LemmaTokenizer()
tokens = [tokenizer.__call__(doc) for doc in bugreports.br_desc]
final_tokens = set()
for token_list in tokens:
    for t in token_list:
        final_tokens.add(t)

#final_tokens = final_tokens.intersection(set())       
final_tokens = sorted(list(final_tokens))
print(final_tokens)

dff = pd.DataFrame(final_tokens)
print(dff.shape)
#display(dff)
# Out:
# ['abruptly', 'actual', 'addition', 'additional', 'around', 'ask', 'awkward', 'blocked', 'branch', 'browsing', 'button', 'case', 'clarify', 'confirmation', 'content', 'contents', 'designed', 'designer', 'dialog', 'downloads', 'end', 'expected', 'experience', 'extent', 'firefox', 'fixed', 'for', 'fxprivacy', 'hence', 'horizontally', 'if', 'left', 'making', 'malware', 'many', 'message', 'modal', 'nan', 'needed', 'new', 'no', 'normal', 'open', 'overflow', 'page', 'panel', 'past', 'potentially', 'presence', 'previous', 'private', 'protrudes', 'read', 'region', 'regression', 'replacement', 'resize', 'resolved', 'results', 'right', 'say', 'scroll', 'scrollable', 'scrollbars', 'see', 'show', 'side', 'size', 'skinny', 'small', 'special', 'str', 'subview', 'surely', 'temporarily', 'text', 'the', 'time', 'true', 'try', 'uncommon', 'unreadable', 'unscrollable', 'unspecified', 'unwanted', 'user', 'using', 'verified', 'viewport', 'wanted', 'way', 'wide', 'window']
# (93, 1)

# %%
X = lsi_model.vectorizer.transform(bugreports.br_desc)
df1 = pd.DataFrame(X.T.toarray())
df1.index = lsi_model.vectorizer.get_feature_names()
df1.rename(columns={0:'BR_1267501_SRC',1:'BR_1292566_SRC'}, inplace=True)
print(df1.shape)
aux_functions.highlight_df(df1)
# Out:
# (98, 2)
# <style  type="text/css" >
#     #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow11_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow13_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow13_col1 {
#             background-color:  #8acc8a;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow14_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow14_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow15_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow15_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow16_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow16_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow17_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow17_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow18_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow18_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow19_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow19_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow20_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow20_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow21_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow21_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow22_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow22_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow23_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow23_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow24_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow24_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow25_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow25_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow26_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow26_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow27_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow27_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow28_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow28_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow29_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_fa5d4b5c_85f1_11eb_a7e0_09e1e13bf2earow29_col1 {
#             background-color:  #

# %%
query_vec = lsi_model._query_vector
query_vec = pd.DataFrame(query_vec)
query_vec.index = bug_reports_names
query_vec
# Out:
#                        0         1         2         3
# br_name
# BR_1267501_SRC  0.340724 -0.096243 -0.132655 -0.119206
# BR_1292566_SRC  0.377781  0.133219  0.603442 -0.201805

# %%
from sklearn.metrics import pairwise
results = pd.DataFrame(pairwise.cosine_similarity(X=svd_matrix, Y=query_vec))
results.index = test_cases_names
results.rename(columns={0:bug_reports_names.values[0],
                        1:bug_reports_names.values[1]}, inplace=True)
aux_functions.highlight_df(results)
# Out:
# <style  type="text/css" >
#     #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow0_col0 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow0_col1 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow1_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow3_col0 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow3_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2ea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >BR_1267501_SRC</th>        <th class="col_heading level0 col1" >BR_1292566_SRC</th>    </tr>    <tr>        <th class="index_name level0" >tc_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2ealevel0_row0" class="row_heading level0 row0" >TC_13_TRG</th>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow0_col0" class="data row0 col0" >0.470123</td>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow0_col1" class="data row0 col1" >0.0679615</td>
#             </tr>
#             <tr>
#                         <th id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2ealevel0_row1" class="row_heading level0 row1" >TC_37_TRG</th>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow1_col0" class="data row1 col0" >0.932144</td>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow1_col1" class="data row1 col1" >0.092866</td>
#             </tr>
#             <tr>
#                         <th id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2ealevel0_row2" class="row_heading level0 row2" >TC_60_TRG</th>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow2_col0" class="data row2 col0" >0.0698727</td>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow2_col1" class="data row2 col1" >0.0449254</td>
#             </tr>
#             <tr>
#                         <th id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2ealevel0_row3" class="row_heading level0 row3" >TC_155_TRG</th>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow3_col0" class="data row3 col0" >0.158545</td>
#                         <td id="T_095aa9e2_85f2_11eb_a7e0_09e1e13bf2earow3_col1" class="data row3 col1" >0.997955</td>
#             </tr>
#     </tbody></table>

# %%
import numpy as np

tokenizer = tok.WordNetBased_LemmaTokenizer()
tokens = [tokenizer.__call__(doc) for doc in testcases.tc_desc]
final_tokens = []
for token_list in tokens:
    for t in token_list:
        final_tokens.append(t)

print(np.unique(final_tokens))
print(len(np.unique(final_tokens)))
# Out:
# ['able' 'active' 'aero' 'after' 'all' 'appearance' 'appears' 'apz' 'arrow'
#  'async' 'awesome' 'awesomebar' 'bar' 'blue' 'browser' 'button' 'changed'
#  'clean' 'click' 'color' 'complete' 'completed' 'config' 'ctrl'
#  'customization' 'customize' 'default' 'disabled' 'display' 'download'
#  'downloads' 'drag' 'dropmaker' 'enabled' 'entry' 'firefox' 'home' 'http'
#  'initiate' 'install' 'installation' 'installed' 'issue' 'jerkiness' 'key'
#  'latest' 'launch' 'launched' 'least' 'lightweight' 'long' 'make'
#  'manager' 'matter' 'menu' 'mode' 'mouse' 'nan' 'navigation' 'new' 'no'
#  'on' 'once' 'open' 'page' 'panel' 'perform' 'place' 'placed' 'positioned'
#  'previous' 'previously' 'process' 'profile' 'properly' 'rendering'
#  'replaces' 'restart' 'restarted' 'scroll' 'scrolling' 'search' 'section'
#  'select' 'set' 'smooth' 'space' 'state' 'successfully' 'sure' 'tab' 'the'
#  'theme' 'true' 'turn' 'ui' 'url' 'use' 'user' 'using' 'web' 'wheel'
#  'white' 'windows' 'without' 'work']
# 106

# %% [markdown]
# Term-by-Document Matrix - SVD Matrix

# %%
df = pd.DataFrame(lsi_model.svd_model.components_.T)
df.index = lsi_model.vectorizer.get_feature_names()
df.rename(columns={0:'TC_13_TRG',1:'TC_37_TRG',2:'TC_60_TRG',3:'TC_155_TRG'}, inplace=True)
print(df.shape)
aux_functions.highlight_df(df)
# Out:
# (98, 4)
# <style  type="text/css" >
#     #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow0_col1 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow0_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow0_col3 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow1_col1 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow1_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow1_col3 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow2_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow2_col1 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow2_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow2_col3 {
#             background-color:  #90d090;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow3_col1 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow3_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow3_col3 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow4_col1 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow4_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow4_col3 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow5_col0 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow5_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow5_col2 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow5_col3 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow6_col0 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow6_col1 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow6_col2 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow6_col3 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow7_col0 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow7_col1 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow7_col2 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow7_col3 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow8_col0 {
#             background-color:  #219221;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow8_col1 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow8_col2 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow8_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow9_col0 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow9_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow9_col2 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow9_col3 {
#             background-color:  #44a644;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow10_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow10_col1 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow10_col2 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow10_col3 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow11_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow11_col1 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow11_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow11_col3 {
#             background-color:  #90d090;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow12_col0 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow12_col1 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow12_col2 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow12_col3 {
#             background-color:  #9ed79e;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow13_col0 {
#             background-color:  #60b560;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow13_col1 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow13_col2 {
#             background-color:  #379e37;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow13_col3 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow14_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow14_col1 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow14_col2 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_24516a10_85f2_11eb_a7e0_09e1e13bf2earow14_col3 {
#             background-color:  #90d090;

# %%
lsi_model.docs_feats_df
# Out:
#                                                               mrw  dl
# TC_13_TRG        [awesome, firefox, launch, bar, url, awesomebar]  23
# TC_37_TRG               [scroll, scrolling, key, make, true, apz]  43
# TC_60_TRG       [theme, complete, browser, install, installati...  52
# TC_155_TRG      [downloads, button, customize, dropmaker, colo...  65
# BR_1267501_SRC           [scroll, window, page, new, using, true]  78
# BR_1292566_SRC   [downloads, panel, button, open, previous, user]  66

# %% [markdown]
# # Introduction
#
# In this notebook we demonstrate the use of **BM25 (Best Matching 25)** Information Retrieval technique to make trace link recovery between Test Cases and Bug Reports.
#
# We model our study as follows:
#
# * Each bug report title, summary and description compose a single query.
# * We use each test case content as an entire document that must be returned to the query made

# %% [markdown]
# # Import Libraries

# %%
from mod_finder_util import mod_finder_util
mod_finder_util.add_modules_origin_search_path()

import pandas as pd
import pprint

from modules.models_runner.feat_br_models_runner import Feat_BR_Models_Runner
from modules.utils import aux_functions
from modules.utils import model_evaluator as m_eval
from modules.utils import firefox_dataset_p2 as fd
from modules.utils import similarity_measures as sm
from modules.utils import br_feat_final_matrix_handler as b2f_handler

from matplotlib import pyplot as plt

import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# # Load Datasets

# %%
bugreports = fd.Datasets.read_selected_bugreports_df()
features = fd.Datasets.read_features_df()
# Out:
# SelectedBugReports.shape: (91, 18)
# Features.shape: (19, 8)

# %% [markdown]
# # Running BM25 Model - Exp-Vol UNION Oracle

# %%
models_runner_1 = Feat_BR_Models_Runner()

bm25_model_1 = models_runner_1.run_bm25_model()

evaluator_1 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_union_df().T)

sim_thresh = 0.0

bm25_eval_t1 = evaluator_1.evaluate_model(model=bm25_model_1, top_value=1, sim_threshold=sim_thresh)
bm25_eval_t3 = evaluator_1.evaluate_model(model=bm25_model_1, top_value=3, sim_threshold=sim_thresh)
bm25_eval_t5 = evaluator_1.evaluate_model(model=bm25_model_1, top_value=5, sim_threshold=sim_thresh)
bm25_eval_t10 = evaluator_1.evaluate_model(model=bm25_model_1, top_value=10, sim_threshold=sim_thresh)
# Out:
# Features.shape: (19, 8)
# SelectedBugReports.shape: (91, 18)
# Running BM25 model -----
# Expert and Volunteers Matrix UNION.shape: (91, 19)

# %% [markdown]
# # Similarity Matrix

# %%
aux_functions.highlight_df(bm25_model_1.get_sim_matrix().iloc[0:23, 0:14])
# Out:
# <style  type="text/css" >
#     #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col0 {
#             background-color:  #6ebd6e;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col1 {
#             background-color:  #1b8f1b;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col4 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col5 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col6 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col7 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col8 {
#             background-color:  #90d090;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col9 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col10 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col11 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col12 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row0_col13 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col0 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col1 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col2 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col3 {
#             background-color:  #a5dba5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col5 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col6 {
#             background-color:  #7cc57c;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col7 {
#             background-color:  #80c780;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col9 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col10 {
#             background-color:  #5fb55f;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col11 {
#             background-color:  #77c277;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col12 {
#             background-color:  #4ba94b;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row1_col13 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col2 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col3 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col4 {
#             background-color:  #61b661;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col5 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col6 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col7 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col10 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col11 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col12 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row2_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col0 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col2 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col3 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col4 {
#             background-color:  #0a850a;
#             color:  #f1f1f1;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col5 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col6 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col7 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col8 {
#             background-color:  #44a544;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col9 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col10 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col11 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col12 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row3_col13 {
#             background-color:  #7ec67e;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row4_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_221818c4_92d4_11e9_8bc8_0d60512283c1row4_col3 {
#             background-color:  #e5ffe5;
#             colo

# %% [markdown]
# # Analysis of BR x Feat Generated Traces

# %%
handler = b2f_handler.BR_Feat_Final_Matrix_Handler(mode=b2f_handler.HandlerMode.LOAD)
br_2_features_matrix_final = handler.add_mappings_1(columns_names=['Features_IDs_bm25_t1_m',
                                                                   'Features_IDs_bm25_t3_m',
                                                                   'Features_IDs_bm25_t5_m',
                                                                   'Features_IDs_bm25_t10_m',
                                                                   'Features_IDs_orc'],
                                                    trace_matrices=[bm25_eval_t1['trace_links_df'],
                                                                    bm25_eval_t3['trace_links_df'],
                                                                    bm25_eval_t5['trace_links_df'],
                                                                    bm25_eval_t10['trace_links_df'],
                                                                    evaluator_1.get_oracle_df()],
                                                    is_from_model=True)

br_2_features_matrix_final = handler.add_mappings_2(dest_columns_names=['f_names_bm25_t1',
                                                                        'f_names_bm25_t3',
                                                                        'f_names_bm25_t5',
                                                                        'f_names_bm25_t10',
                                                                        'f_names_orc'],
                                                   orig_columns_names=['Features_IDs_bm25_t1_m',
                                                                       'Features_IDs_bm25_t3_m',
                                                                       'Features_IDs_bm25_t5_m',
                                                                       'Features_IDs_bm25_t10_m',
                                                                       'Features_IDs_orc'])
br_2_features_matrix_final.head(10)
# Out:
# SelectedBugReports.shape: (91, 18)
# Features.shape: (19, 8)
# BR_2_Features Matrix Final.shape: (91, 5)
#                                                     bug_title  \
# Bug_Number
# 1248267     Right click on bookmark item of "Recently Book...
# 1248268               Unable to disable "Recently bookmarked"
# 1257087     Middle mouse click on history item would not open
# 1264988     Scrollbar appears for a moment in the new Awes...
# 1267480     Intermittent browser/components/preferences/in...
# 1267501     New Private Browsing start-page overflows off ...
# 1269348     Show last sync date tooltip on Synced Tabs sid...
# 1269485     New Private Browsing start-page has white/gray...
# 1270274     Intermittent browser_share.jsuncaught exceptio...
# 1270983     Intermittent browser_contextmenu.jsTest timed ...
#
#            Features_IDs_exp_m Features_IDs_vol_m Features_IDs_exp_vol_union_m  \
# Bug_Number
# 1248267                     6                  6                            6
# 1248268                                        4                            4
# 1257087
# 1264988                     1                  1                            1
# 1267480
# 1267501                     3                                               3
# 1269348
# 1269485                     3                                               3
# 1270274
# 1270983                     6                  6                            6
#
#            Features_IDs_exp_vol_intersec_m Features_IDs_bm25_t1_m  \
# Bug_Number
# 1248267                                  6                      6
# 1248268                                                         6
# 1257087                                                         1
# 1264988                                  1                      1
# 1267480                                                         2
# 1267501                                                         7
# 1269348                                                        18
# 1269485                                                         7
# 1270274                                                         2
# 1270983                                  6                      6
#
#            Features_IDs_bm25_t3_m Features_IDs_bm25_t5_m  \
# Bug_Number
# 1248267                     1 6 7             1 2 6 7 12
# 1248268                     1 2 6            1 2 6 12 14
# 1257087                    1 6 12             1 2 6 7 12
# 1264988                     1 2 6             1 2 6 7 19
# 1267480                    2 4 16            2 4 9 11 16
# 1267501                     1 6 7              1 3 6 7 8
# 1269348                   1 14 18           1 6 14 18 19
# 1269485                     1 6 7              1 2 3 6 7
# 1270274                    2 4 17            2 4 9 16 17
# 1270983                     1 6 7             1 4 6 7 12
#
#               Features_IDs_bm25_t10_m Features_IDs_orc  \
# Bug_Number
# 1248267      1 2 4 6 7 12 13 14 17 19                6
# 1248268     1 2 6 7 10 12 14 16 17 18                4
# 1257087        1 2 3 4 6 7 9 12 17 19
# 1264988       1 2 4 6 7 9 12 16 17 19                1
# 1267480       2 3 4 7 8 9 10 11 12 16
# 1267501        1 2 3 6 7 8 9 12 13 14                3
# 1269348       1 2 4 6 7 8 12 14 18 19
# 1269485        1 2 3 6 7 8 9 12 13 17                3
# 1270274      2 4 7 8 9 10 11 12 16 17
# 1270983       1 4 6 7 8 9 10 11 12 16                6
#
#                       f_names_bm25_t1  \
# Bug_Number
# 1248267              [[context_menu]]
# 1248268              [[context_menu]]
# 1257087           [[new_awesome_bar]]
# 1264988           [[new_awesome_bar]]
# 1267480        [[windows_child_mode]]
# 1267501                  [[w10_comp]]
# 1269348     [[indicator_device_perm]]
# 1269485                  [[w10_comp]]
# 1270274        [[windows_child_mode]]
# 1270983              [[context_menu]]
#
#                                               f_names_bm25_t3  \
# Bug_Number
# 1248267       [[new_awesome_bar], [context_menu], [w10_comp]]
# 1248268     [[new_awesome_bar], [windows_child_mode], [con...
# 1257087     [[new_awesome_bar], [context_menu], [pointer_l...
# 1264988     [[new_awesome_bar], [windows_child_mode], [con...
# 1267480     [[windows_child_mode], [browser_customization]...
# 1267501       [[new_awesome_bar], [context_menu], [w10_comp]]
# 1269348     [[new_awesome_bar], [zoom_indicator], [indicat...
# 1269485       [[new_awesome_bar], [context_menu], [w10_comp]]
# 1270274     [[windows_child_mode], [browser_customization]...
# 1270983       [[new_awesome_bar], [context_menu], [w10_comp]]
#
#                                               f_names_bm25_t5  \
# Bug_Number
# 1248267     [[new_awesome_bar], [windows_child_mode], [con...
# 1248268     [[new_awesome_bar], [windows_child_mode], [con...
# 1257087     [[new_awesome_bar], [windows_child_mode], [con...
# 1264988     [[new_awesome_bar], [windows_child_mode], [con...
# 1267480     [[windows_child_mode], [browser_customization]...
# 1267501     [[new_awesome_bar], [apz_async_scrolling], [co...
# 1269348     [[new_awesome_bar], [context_menu], [zoom_indi...
# 1269485     [[new_awesome_bar], [windows_child_mode], [apz...
# 1270274     [[windows_child_mode], [browser_customization]...
# 1270983     [[new_awesome_bar], [browser_customization], [...
#
#                                              f_names_bm25_t10  \
# Bug_Number
# 1248267     [[new_awesome_bar], [windows_child_mode], [bro...
# 1248268     [[new_awesome_bar], [windows_child_mode], [con...
# 1257087     [[new_awesome_bar], [windows_child_mode], [apz...
# 1264988     [[new_awesome_bar], [windows_child_mode], [bro...
# 1267480     [[windows_child_mode], [apz_async_scrolling], ...
# 1267501     [[new_awesome_bar], [windows_child_mode], [apz...
# 1269348     [[new_awesome_bar], [windows_child_mode], [bro...
# 1269485     [[new_awesome_bar], [windows_child_mode], [apz...
# 1270274     [[windows_child_mode], [browser_customization]...
# 1270983     [[new_awesome_bar], [browser_customization], [...
#
#                           f_names_orc
# Bug_Number
# 1248267              [[context_menu]]
# 1248268     [[browser_customization]]
# 1257087                            []
# 1264988           [[new_awesome_bar]]
# 1267480                            []
# 1267501       [[apz_async_scrolling]]
# 1269348                            []
# 1269485       [[apz_async_scrolling]]
# 1270274                            []
# 1270983              [[context_menu]]

# %% [markdown]
# # Analysis of Precision and Recall

# %% [markdown]
# ## Union Strategy

# %%
results_1 = evaluator_1.run_evaluator(models=[bm25_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_1.plot_evaluations_2(title='BM25 Evaluation | Exp-Vol UNION', results=results_1, model_name='bm25')
# Out:
# Evaluating BM25 Model -----

# %% [markdown]
# ## Intersection Strategy

# %%
evaluator_2 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_volunteers_intersec_df().T)
results_2 = evaluator_2.run_evaluator(models=[bm25_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_2.plot_evaluations_2(title='BM25 Evaluation | Exp-Vol INTERSECTION', results=results_2, model_name='bm25')
# Out:
# Expert and Volunteers Matrix INTERSEC.shape: (91, 19)
# Evaluating BM25 Model -----

# %% [markdown]
# ## Expert-Only Strategy

# %%
evaluator_3 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_expert_df().T)
results_3 = evaluator_3.run_evaluator(models=[bm25_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_3.plot_evaluations_2(title='BM25 Evaluation | Expert-Only', results=results_3, model_name='bm25')
# Out:
# Feat_BR Expert Matrix shape: (91, 19)
# Evaluating BM25 Model -----

# %% [markdown]
# ## Volunteers-Only Strategy

# %%
evaluator_4 = m_eval.ModelEvaluator(oracle=fd.Feat_BR_Oracles.read_feat_br_volunteers_df().T)
results_4 = evaluator_4.run_evaluator(models=[bm25_model_1], top_values=[1,3,5], sim_thresholds=[(sm.SimilarityMeasure.COSINE, s_thresh/10) for s_thresh in range(0,10)])
evaluator_4.plot_evaluations_2(title='BM25 Evaluation | Volunteers-Only', results=results_4, model_name='bm25')
# Out:
# Feat_BR Volunteers Matrix shape: (91, 19)
# Evaluating BM25 Model -----
